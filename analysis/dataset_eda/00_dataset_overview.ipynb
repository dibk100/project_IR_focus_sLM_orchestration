# %% [markdown]
# # data_EDA_overview
# 데이터셋이 실제로 sLM 파이프라인에서 어떤 입력/출력 단위를 가지는지 눈으로 이해하는 EDA작업을 진행하기.

# %% [markdown]
# ```
# analysis/data_eda/
# ├── 00_dataset_overview.ipynb
# ├── 01_humaneval_eda.ipynb
# ├── 02_bigcode_eda.ipynb
# └── utils/
# ```

# %% [markdown]
# ---
# ### 1차 분석
# log.2026.04.09

# %% [markdown]
# #### HumanEval → 함수 완성
# - 입력에 함수틀을 넣음. 고정된 템플릿을 모델에 입력함.
# - 사실상 하나의 함수 성공하는 TASK
# → orchestration이 reasoning 측면에서만 개선 가능
#
# #### MBPP → 프로그램 생성
# - 자연어만 입력하여 함수, 클래스 등을 생성하게 하는 TASK
# - 코드의 구조 자체도 이해할 수 알아야함. structure generation 문제
# → orchestration이 가장 효과적으로 작동할 환경

# %% [markdown]
# ### README에 기록함
# 지표를 3가지로 쪼개보고자 함.
#
# #### (1) execution success rate : **strutural**
# exec(code) 성공 비율(코드 실행)
#
# #### (2) pass rate : **overall**
# test 통과 비율(코드 실행 + test 성공)
#
# #### (3) conditional pass : **semantic**
# pass/exec_success
# 실행 가능한 코드 중에서, 실제로 정답인 비율
#
# ### 정리
# orchestration → exec success ↑ ? (구조 개선)
# orchestration → pass ↑ ? (전체 성능)
# orchestration → conditional pass ↑ ? (의미 개선)
